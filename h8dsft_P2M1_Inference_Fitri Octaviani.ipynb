# %% [markdown]
# # Import Library

# %%
# import library
from tensorflow import keras
import pandas as pd
import numpy  as np
import joblib
from tensorflow.keras.models import load_model

# %% [markdown]
# # Load Model

# %%
# load preprocessor
with open('preprocessor.pkl','rb') as file_1:
    preprocessor = joblib.load(file_1)

# %%
# load ANN model
model = load_model('sequen_imp_model.h5')

# %% [markdown]
# # Data Loading

# %%
df_infer = pd.read_csv('h8dsft_P2M1_inference_Fitri Octaviani.csv')

# %%
df_infer.head()
# Out:
#    Unnamed: 0  age gender region_category membership_category  \
# 0        3479   59      M            Town     Gold Membership
# 1        9414   26      F            City    Basic Membership
# 2       15760   49      M            Town    Basic Membership
# 3       16668   21      F            Town    Basic Membership
# 4       17542   62      F             NaN    Basic Membership
#
#   joined_through_referral     preferred_offer_types medium_of_operation  \
# 0                      No            Without Offers             Desktop
# 1                      No     Gift Vouchers/Coupons             Desktop
# 2                     NaN            Without Offers             Desktop
# 3                     Yes     Gift Vouchers/Coupons          Smartphone
# 4                     Yes  Credit/Debit Card Offers          Smartphone
#
#   internet_option  days_since_last_login  ...  avg_transaction_value  \
# 0           Wi-Fi                      9  ...               43978.54
# ...

# %%
data_inf = df_infer.copy()
data_inf = df_infer.drop(['Unnamed: 0'],axis=1)
data_inf.head(2)
# Out:
#    age gender region_category membership_category joined_through_referral  \
# 0   59      M            Town     Gold Membership                      No
# 1   26      F            City    Basic Membership                      No
#
#    preferred_offer_types medium_of_operation internet_option  \
# 0         Without Offers             Desktop           Wi-Fi
# 1  Gift Vouchers/Coupons             Desktop           Wi-Fi
#
#    days_since_last_login  avg_time_spent  avg_transaction_value  \
# 0                      9          395.30               43978.54
# 1                     16          220.86               33749.09
#
#    avg_frequency_login_days  points_in_wallet used_special_discount  \
# 0                       0.0            789.60                   Yes
# 1                      15.0            521.36                   Yes
#
#   offer_application_preference past_complaint complaint_status  \
# 0                          Yes             No   Not Applicable
# ...

# %% [markdown]
# # Model Inference

# %%
# preprocess data before feedforwarding into the model
preprocessed_data = preprocessor.transform(data_inf)

# %%
# predict result
predictions = model.predict(preprocessed_data)
# Out:
# 1/1 [==============================] - 0s 165ms/step

# %%
# convert prediction probability to each appropriate target class
pred = np.where(predictions>0.5,1,0)

# %%
# show data infer + prediction
data_inf['churn_risk_score'] = pred
data_inf.head(2)
# Out:
#    age gender region_category membership_category joined_through_referral  \
# 0   59      M            Town     Gold Membership                      No
# 1   26      F            City    Basic Membership                      No
#
#    preferred_offer_types medium_of_operation internet_option  \
# 0         Without Offers             Desktop           Wi-Fi
# 1  Gift Vouchers/Coupons             Desktop           Wi-Fi
#
#    days_since_last_login  avg_time_spent  avg_transaction_value  \
# 0                      9          395.30               43978.54
# 1                     16          220.86               33749.09
#
#    avg_frequency_login_days  points_in_wallet used_special_discount  \
# 0                       0.0            789.60                   Yes
# 1                      15.0            521.36                   Yes
#
#   offer_application_preference past_complaint complaint_status  \
# 0                          Yes             No   Not Applicable
# ...
